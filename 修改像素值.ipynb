# %%
import matplotlib.pyplot as plt
import os

# %%
path = r"C:\Users\asus\Desktop\医院\图像像素\增强.jpg"

# %%
x = plt.imread(path)

# %%
plt.imshow(x)

# %%
plt.savefig(os.path.join(r"C:\Users\asus\Desktop\医院\图像像素", "增强" + "jpg"), dpi=1000)
